# %% [markdown]
# ## import the library

# %%
import mysql.connector as connector
import pandas as pd

# %% [markdown]
# # create a connection to database

# %%
try: 
    conn = connector.connect(host="localhost", db="mysql" ,user="root" ,password="Mysql123")
except connector.Error as e: 
    print("Error: Could not make connection to the Mysql database")
    print(e)

# %% [markdown]
# # Use the connection to get a cursor that can be used to execute queries.

# %%
try: 
    cur = conn.cursor()
except connector.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

# %% [markdown]
# # Set automatic commit to be true so that each action is committed without having to call conn.commit() after each command.

# %%
conn.autocommit=True

# %% [markdown]
# ## Create a database

# %%
try: 
    cur.execute("create database wealthinfo")
except connector.Error as e:
    print(e)
# Out:
# 1007 (HY000): Can't create database 'wealthinfo'; database exists

# %% [markdown]
# ## Closing the connection to default mysql database and creating connection to new database

# %%
try: 
    conn.close()
except connector.Error as e:
    print(e)
    
try: 
    conn = connector.connect(host="localhost", db="wealthinfo" ,user="root" ,password="Mysql123")
except connector.Error as e: 
    print("Error: Could not make connection to the mysql database")
    print(e)
    
try: 
    cur = conn.cursor()
except connector.Error as e: 
    print("Error: Could not get cursor to the Database")
    print(e)

# %% [markdown]
# ## Reading the data from csv file

# %%
AccountsCountryRaw=pd.read_csv("data/Wealth-AccountsCountry.csv")

# %%
AccountsCountryRaw.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry=AccountsCountryRaw[['Code','Short Name','Table Name','Long Name','Currency Unit']]

# %%
AccountsCountry.head()
# Out:
#   Code Short Name Table Name                  Long Name      Currency Unit
# 0  ALB    Albania    Albania        Republic of Albania       Albanian lek
# 1  ARG  Argentina  Argentina         Argentine Republic     Argentine peso
# 2  ARM    Armenia    Armenia        Republic of Armenia      Armenian dram
# 3  AUS  Australia  Australia  Commonwealth of Australia  Australian dollar
# 4  AUT    Austria    Austria        Republic of Austria               Euro

# %%
AccountsCountry.drop_duplicates(subset="Code")
# Out:
#      Code          Short Name          Table Name                  Long Name  \
# 0     ALB             Albania             Albania        Republic of Albania
# 1     ARG           Argentina           Argentina         Argentine Republic
# 2     ARM             Armenia             Armenia        Republic of Armenia
# 3     AUS           Australia           Australia  Commonwealth of Australia
# 4     AUT             Austria             Austria        Republic of Austria
# ...   ...                 ...                 ...                        ...
# 142   PSE  West Bank and Gaza  West Bank and Gaza         West Bank and Gaza
# 143   YEM               Yemen         Yemen, Rep.          Republic of Yemen
# 144   ZMB              Zambia              Zambia         Republic of Zambia
# 145   ZWE            Zimbabwe            Zimbabwe       Republic of Zimbabwe
# 7592  NaN                 NaN                 NaN                        NaN
#
#            Currency Unit
# ...

# %%
AccountDataRaw=pd.read_csv("data/Wealth-AccountData.csv")

# %%
AccountDataRaw.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountDataRaw.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountData=AccountDataRaw[['Country Name', 'Country Code', 'Series Name', 'Series Code','2000 [YR2000]','2010 [YR2010]','2018 [YR2018]']]

# %%
AccountData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   2000 [YR2000]  2010 [YR2010] 2018 [YR2018]
# 0      4.36E+10   6.810000e+10      8.12E+10
# 1      14118.13   2.336286e+04      28333.68
# 2      3424.007   2.889150e+03      3312.927
# 3      6872.019   1.578992e+04      19245.19
# 4      4695.071   3.613606e+03      4161.137

# %%
AccountData=AccountData.drop_duplicates(subset="Country Code")

# %%
AccountSeriesRaw=pd.read_csv("data/Wealth-AccountSeries.csv")

# %%
AccountSeriesRaw.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountSeries=AccountSeriesRaw[['Code','Topic','Indicator Name']]

# %%
AccountSeries.head()
# Out:
#              Code          Topic  \
# 0       NW.HCA.TO  Human capital
# 1       NW.HCA.PC  Human capital
# 2  NW.HCA.FEMP.PC  Human capital
# 3  NW.HCA.MEMP.PC  Human capital
# 4  NW.HCA.FEMA.PC  Human capital
#
#                                       Indicator Name
# 0                  Human capital (constant 2018 US$)
# 1       Human capital per capita (constant 2018 US$)
# 2  Human capital per capita, employed female (con...
# 3  Human capital per capita, employed male (const...
# 4  Human capital per capita, female (constant 201...

# %%
accounts_country_table_create=("""CREATE TABLE IF NOT EXISTS accountscountry(
country_code varchar(50),
short_name varchar(50),
table_name varchar(50),
Long_name varchar(100),
currency_unit varchar(50)
)""")

# %%
cur.execute(accounts_country_table_create)

# %%
account_data_table_create=("""CREATE TABLE IF NOT EXISTS accountdata(
country_name varchar(50),
country_code varchar(50),
series_name varchar(50),
series_code varchar(50),
year_2000 varchar(50),
year_2010 varchar(50),
year_2018 varchar(50)
)""")

# %%
cur.execute(account_data_table_create)

# %%
accounts_series=("""CREATE TABLE IF NOT EXISTS accountseries(
code varchar(50),
topic varchar(50),
indicator_name varchar(500))""")

# %%
cur.execute(accounts_series)

# %%
accounts_country_table_insert=("""INSERT INTO accountscountry(
country_code,
short_name,
table_name,
Long_name,
currency_unit)
VALUES(%s,%s,%s,%s,%s)
""")

# %%
for i,row in AccountsCountry.iterrows():
    #print(list(row))
    cur.execute(accounts_country_table_insert,list(row))

# %%
conn.commit()

# %%
account_data_table_insert=("""INSERT INTO accountdata(
country_name,
country_code,
series_name,
series_code,
year_2000,
year_2010,
year_2018)
VALUES(%s,%s,%s,%s,%s,%s,%s)
""")

# %%
for i,row in AccountData.iterrows():
    #print(list(row))
    cur.execute(account_data_table_insert,list(row))

# %%
conn.commit()

# %%
account_series_table_insert=("""INSERT INTO accountseries(
code,
topic,
indicator_name)
VALUES(%s,%s,%s)
""")

# %%
for i,row in AccountSeries.iterrows():
    #print(list(row))
    cur.execute(account_series_table_insert,list(row))

# %%
conn.commit()
